# %% [markdown]
# <h1>Group Project: considerations on demographic of self-taught coders</h1>
# <br><br>
# <h2>Introduction</h2>
# <p align="justify">
# With the purpose of understanding a bit better the profile of self-taught online students that are part of the “Learn to Code” movement the Team 39 agreed that we would use data freely available on Kaggle platform, made available by freeCodeCamp to understand different profiles presented and find relevant trends to understand strong influence that trend alrady have and help finding "niches" where engagement can be reinforced in order to broaden the reach of movement.
# </p>
# <br>
# <h2>Data analysed</h2>
# <p align="justify">For this study we will use data made available online by freeCodeCamp (https://github.com/freeCodeCamp/2016-new-coder-survey ).
# The survey was designed by CodeNewbie and Free Code Camp as an anonymous 5-minute survey, to with more than 15,000 participants from 169 countries have answered to from March 28 through May 2 (2016).
# The 2016 New Coder Survey is made available under the Open Database License: http://opendatacommons.org/licenses/odbl/1.0/. Any rights in individual contents of the database are licensed under the Database Contents License: http://opendatacommons.org/licenses/dbcl/1.0/
# </p>
# <br>
# <h2>Definition of activities</h2>
# <p align="justify">Udacity Data Scholars beneficiaries of Bertelsmann Data Science Challenge Scholarship Course and participants of Team 39 listed different interesting aspects that could be derived from questions available on survey, the suggestions were voted and top three divided between each of three subgroups, as follows:
# </p>

# %% [markdown]
# |<p align="center">Question<br>IDs</p>|<p align="left">Topic</p>|<p align="left">Subgroup</p>|
# |-----|--------------------|----------|
# |<p align="center">1.08; 1.09; 1.10; 1.13; 2.08</p>|<p align="justify">Questions “2.08. What’s the highest degree or level of school you have completed? (If currently enrolled, highest degree received.)” and “1.08. Which types of in-person coding events have you attended?”, “1.09. Which learning resources have you found helpful?”, “1.10. Which coding-related podcasts have you found helpful?” and "1.13. Have you attended a full-time coding bootcamp?" to show what is the level of education of people seeking alternative methods of continuous learning training (bootcamps/online/podcast).</p>|<p align="left">Butterflies - Isabel Martinez (IM), Loretta Rehm (LR), Nelly Hilmane (NH)</p>|
# |<p align="center">1.01; 1.03; 1.09</p>|<p align="justify">1.01. Are you already working as a software developer? 1.03. Which one of these roles are you most interested in? 1.09. Which learning resources have you found helpful?- To determine the popularity of online courses/self study.</p>|<p align="left">Dragonflies - Kashan Khan (K.K), Mohamed Hassona (MH), Ramya Kameshwar (RK)</p>|
# |<p align="center">1.11; 2.01; 2.02</p>|<p align="justify">2.01. compare age, 2.02. gender to 1.11. hours spent studying</p>|<p align="left">Ladybirds - Ana Sustic (AS), Elena Lestini (EL), Rudo N Takavarasha (RNT)</p>|

# %% [markdown]
# <p align="justify">
# <h3>Questions from survey that were analysed are:</h3>
# <br>
# 1.08: Which types of in-person coding events have you attended?<br>
# 1.09: Which learning resources have you found helpful?<br>
# 1.10: Which coding-related podcasts have you found helpful?<br>
# 1.13: Have you attended a full-time coding bootcamp?<br>
# 2.08: What's the highest degree or level of school you have completed? (If currently enrolled, highest degree received.)
# <br><br>
# With the purpose to highlight the variance on level of education of people seeking any of the alternatives of continuous learning included in the survey: coding events, online courses, podcasts and bootcamps.
# </p>

# %%
#import pandas lib and data for study
import csv
import numpy as np
import pandas as pd

url = 'https://github.com/freeCodeCamp/2016-new-coder-survey/blob/master/clean-data/2016-FCC-New-Coders-Survey-Data.csv'
rawURL = 'https://raw.githubusercontent.com/freeCodeCamp/2016-new-coder-survey/master/clean-data/2016-FCC-New-Coders-Survey-Data.csv'

#feeding variables that will be cross-linked to form histogram 
reader = pd.read_csv(rawURL, usecols=[1,2,110], sep = ',', dtype = str, iterator=True, chunksize=10000, engine = 'python', encoding = 'utf-8', error_bad_lines = False, warn_bad_lines = True)

#for chunk in reader:
#    print(chunk)

df = pd.concat(list(reader),ignore_index = True)
df.query()

#plot histogram
#print(df.loc[:].hist())
# Out:
#       AttendedBootcamp BootcampFinish  \
# 0                    0            nan
# 1                    0            nan
# 2                    0            nan
# 3                    0            nan
# 4                    0            nan
# 5                    0            nan
# 6                    0            nan
# 7                    0            nan
# 8                    0            nan
# 9                    0            nan
# 10                   0            nan
# 11                   0            nan
# 12                   0            nan
# 13                   0            nan
# 14                   0            nan
# 15                   0            nan
# 16                   0            nan
# 17                   0            nan
# 18                   0            nan
# 19                   0            nan
# 20                   0            nan
# 21                   0            nan
# 22                   0            nan
# 23                   0            nan
# 24                   0            nan
# 25                   0            nan
# 26                   0            nan
# 27                   0            nan
# 28                   0            nan
# 29                   0            nan
# ...                ...            ...
# 15590                0            nan
# 15591                0            nan
# 15592                0            nan
# 15593                0            nan
# 15594                0            nan
# 15595                0            nan
# 15596                0            nan
# 15597                0            nan
# 15598                0            nan
# 15599                0            nan
# 15600                0            nan
# 15601                0            nan
# 15602                0            nan
# 15603                0            nan
# 15604                0            nan
# 15605                0            nan
# 15606                0            nan
# 15607                0            nan
# 15608                0            nan
# 15609                0            nan
# 15610                0            nan
# 15611                0            nan
# 15612                0            nan
# 15613                0            nan
# 15614                0            nan
# 15615                0            nan
# 15616                0            nan
# 15617                0            nan
# 15618                0            nan
# 15619                0            nan
#
#                                    SchoolDegree
# 0                some college credit, no degree
# 1                some college credit, no degree
# 2       high school diploma or equivalent (GED)
# 3                             bachelor's degree
# 4                some college credit, no degree
# 5                             bachelor's degree
# 6                             bachelor's degree
# 7            master's degree (non-professional)
# 8                             bachelor's degree
# 9            master's degree (non-professional)
# 10                            bachelor's degree
# 11               some college credit, no degree
# 12                            bachelor's degree
# 13                            bachelor's degree
# 14      professional degree (MBA, MD, JD, etc.)
# 15                            bachelor's degree
# 16                            bachelor's degree
# 17                            bachelor's degree
# 18               some college credit, no degree
# 19                            bachelor's degree
# 20                            bachelor's degree
# 21                            bachelor's degree
# 22                            bachelor's degree
# 23               some college credit, no degree
# 24      high school diploma or equivalent (GED)
# 25                            bachelor's degree
# 26               some college credit, no degree
# 27               some college credit, no degree
# 28                            bachelor's degree
# 29      high school diploma or equivalent (GED)
# ...                                         ...
# 15590                                     Ph.D.
# 15591                         bachelor's degree
# 15592                        associate's degree
# 15593                         bachelor's degree
# 15594                                     Ph.D.
# 15595            some college credit, no degree
# 15596   professional degree (MBA, MD, JD, etc.)
# 15597   high school diploma or equivalent (GED)
# 15598   professional degree (MBA, MD, JD, etc.)
# 15599  trade, technical, or vocational training
# 15600                         bachelor's degree
# 15601                         bachelor's degree
# 15602                         bachelor's degree
# 15603                         bachelor's degree
# 15604   professional degree (MBA, MD, JD, etc.)
# 15605        master's degree (non-professional)
# 15606   professional degree (MBA, MD, JD, etc.)
# 15607                          some high school
# 15608                         bachelor's degree
# 15609                         bachelor's degree
# 15610                         bachelor's degree
# 15611        master's degree (non-professional)
# 15612   high school diploma or equivalent (GED)
# 15613                         bachelor's degree
# 15614   high school diploma or equivalent (GED)
# 15615                        associate's degree
# 15616                         bachelor's degree
# 15617   professional degree (MBA, MD, JD, etc.)
# 15618   professional degree (MBA, MD, JD, etc.)
# 15619  trade, technical, or vocational training
#
# [15620 rows x 3 columns]
